# %%
####  AND  ###

age = 30
mark = 50
if age >=30 and mark <= 50:
    print("eligible")
# Out:
# eligible

# %%
member = input("are u a member?")
amount = int(input("enter a purchasing amount:"))

if member == "yes" and amount >=5000:
    print("discount activate:")
else:
    print("no discount")
# Out:
# are u a member? yes
# enter a purchasing amount: 4000
# no discount

# %%
member = input("are u a member?")
amount = int(input("enter a purchasing amount:"))

if member == "yes" and amount >=5000:
    print("discount activate")
else:
    print("no discount")
# Out:
# are u a member? yes
# enter a purchasing amount: 6000
# discount activate

# %%
####  OR  ####

age = 16
mark = 90

if age >= 18 or mark >=80:
    print("Allowed")
# Out:
# Allowed

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Login")
# Out:
# Enter username:  admin
# Enter password:  1234
# Login Successful

# %%
age = int(input("Enter age: "))
mark = int(input("Enter mark: "))

if age >= 18 or mark >= 50:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Enter age:  11
# Enter mark:  40
# Not Eligible

# %%
age = int(input("Enter age: "))
mark = int(input("Enter mark: "))

if age >= 18 or mark >= 50:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Enter age:  18
# Enter mark:  66
# Eligible

# %%
#### NOT ####

is_raining = False

if not is_raining:
    print("Go outside")
# Out:
# Go outside

# %%
is_connected = False

if not is_connected:
    print("Please check your internet connection")
else:
    print("Internet is connected")
# Out:
# Please check your internet connection

# %%
is_absent = False

if not is_absent:
    print("Present")
else:
    print("Absent")
# Out:
# Present
