# %%
# VARIABLE

name =  "tamilmaran"
print(name)
# Out:
# tamilmaran

# %%
age = "22"
print(age)
# Out:
# 22

# %%
height = "187"
print(height)
# Out:
# 187

# %%
is_student = "true"
print(is_student)
# Out:
# true

# %%
# DATA TYPES

name = "Tamilmaran"   # str
age = 22              # int
height = 186.5        # float
is_student = True     # bool

# %%
# TYPE

name = "tamilmaran"
print(type(name))
# Out:
# <class 'str'>

# %%
age = 22

print(type(age))
# Out:
# <class 'int'>

# %%
height = "186"
print(type(height))
# Out:
# <class 'str'>

# %%
is_student = True
print(type(is_student))
# Out:
# <class 'bool'>

# %%
name = "kesavan"
age = 35
college = "srm college" 
department = "AI&DS"

print(name)
print(age)
print(college)
print(department)
# Out:
# kesavan
# 35
# srm college
# AI&DS

# %%
# INPUT

name = input("Enter your name: ")
print(name)
# Out:
# Enter your name:  tamil
# tamil

# %%
# INT(INPUT)

age = int(input("Enter your age:"))
print(age+5)
# Out:
# Enter your age: 50
# 55

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
college = input("Enter your college: ")
department = input("Enter your department: ")

print("Student Details")
print("---------------")
print("Name :", name)
print("Age :", age)
print("College :", college)
print("Department :", department)

print(type(name))
print(type(age))
print(type(college))
print(type(department))
# Out:
# Enter your name:  karthi
# Enter your age:  60
# Enter your college:  rsr engineering college
# Enter your department:  cse
# Student Details
# ---------------
# Name : karthi
# Age : 60
# College : rsr engineering college
# Department : cse
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
