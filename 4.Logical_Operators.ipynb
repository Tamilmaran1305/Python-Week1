# %%
### (AND)  ###

a = 10
b = 20

print(a < b and b > 15)
# Out:
# True

# %%
a = 10
b = 20

print(a > b and b > 15)
# Out:
# False

# %%
print(5<10 and 8>3)
# Out:
# True

# %%
print(10 > 20 and 5 < 8)
# Out:
# False

# %%
#### (OR) ####

a = 10
b = 20

print(a > b or b > 15)
# Out:
# True

# %%
a = 10
b = 20

print(a > b or b < 15)
# Out:
# False

# %%
print(5 > 10 or 8 > 3)
# Out:
# True

# %%
print(10 > 20 or 30 < 15)
# Out:
# False

# %%
#### NOT ####

a = 10

print(not(a > 5))
# Out:
# False

# %%
a = 2

print(not(a > 5))
# Out:
# True

# %%
print(not(5 > 2))
# Out:
# False

# %%
print(not(10 < 3))
# Out:
# True
