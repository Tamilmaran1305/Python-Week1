# %%
##### NESTED IF #####

age = 20
has_id = True

if age >= 18:
    print("Age eligible")

    if has_id:
        print("Entry Allowed")
    else:
        print("ID Required")

else:
    print("Not Eligible")
# Out:
# Age eligible
# Entry Allowed

# %%
age = 20
has_id = True

if age >= 18:
    print("Age eligible")

    if not has_id:
        print("Entry Allowed")
    else:
        print("ID Required")

else:
    print("Not Eligible")
# Out:
# Age eligible
# ID Required

# %%
username = input("Enter a username:")
password = input("Enter a password:")

if username == "admin" and password == "4444":
     print("admin successfully activate")

     role = input("enter role:")

     if role == "developer":
         print("developer access")
     else:
         print("not developer")

else:
    print("admin not activate")
# Out:
# Enter a username: admin
# Enter a password: 4444
# admin successfully activate
# enter role: developer
# developer access

# %%
username = input("Enter a username:")
password = input("Enter a password:")

if username == "admin" and password == "4444":
     print("admin successfully activate")

     role = input("enter role:")

     if role == "developer":
         print("developer access")
     else:
         print("not developer")

else:
    print("admin not activate")
# Out:
# Enter a username: tamil
# Enter a password: 4444
# admin not activate

# %%
username = input("Enter a username:")
password = input("Enter a password:")

if username == "admin" and password == "4444":
     print("admin successfully activate")

     role = input("enter role:")

     if role == "developer":
         print("developer access")
     else:
         print("not developer")

else:
    print("admin not activate")
# Out:
# Enter a username: admin
# Enter a password: 4444
# admin successfully activate
# enter role: tester
# not developer

# %%
pin = int(input("Enter a pin :"))

if pin == 9876:
          print("ok")

          balance = 5000
          amount = int(input("Enter a amount:"))

          if amount <= balance:
              print("withdrawal successfull")
              print("remaining balance:",balance-amount)
          else:
              print("insufficient balance")

else:
     print("wrong pin")
# Out:
# Enter a pin : 9876
# ok
# Enter a amount: 3000
# withdrawal successfull
# remaining balance: 2000

# %%
pin = int(input("Enter a pin :"))

if pin == 9876:
          print("ok")

          balance = 5000
          amount = int(input("Enter a amount:"))

          if amount <= balance:
              print("withdrawal successfull")
              print("remaining balance:",balance-amount)
          else:
              print("insufficient balance")

else:
     print("wrong pin")
# Out:
# Enter a pin : 8640
# wrong pin

# %%
pin = int(input("Enter a pin :"))

if pin == 9876:
          print("ok")

          balance = 5000
          amount = int(input("Enter a amount:"))

          if amount <= balance:
              print("withdrawal successfull")
              print("remaining balance:",balance-amount)
          else:
              print("insufficient balance")

else:
     print("wrong pin")
# Out:
# Enter a pin : 9876
# ok
# Enter a amount: 6000
# insufficient balance

# %%
payment = input("Is payment successful? ")
 
if payment == "yes":
    print("Payment successful")

    stock = input("Is product in stock? ")

    if stock == "yes":
        print("Order Confirmed")
    else:
        print("Out of Stock")

else:
    print("Payment Failed")
# Out:
# Is payment successful?  yes
# Payment successful
# Is product in stock?  yes
# Order Confirmed

# %%
payment = input("Is payment successful? ")
 
if payment == "yes":
    print("Payment successful")

    stock = input("Is product in stock? ")

    if stock == "yes":
        print("Order Confirmed")
    else:
        print("Out of Stock")

else:
    print("Payment Failed")
# Out:
# Is payment successful?  yes
# Payment successful
# Is product in stock?  no
# Out of Stock

# %%
degree = input("Do you have a degree? ")

if degree == "yes":
    print("Degree verified")

    experience = int(input("Enter years of experience: "))

    if experience >= 1:
        print("Eligible for experienced role")
    else:
        print("Eligible for fresher/trainee role")

else:
    print("Not Eligible")
# Out:
# Do you have a degree?  yes
# Degree verified
# Enter years of experience:  0
# Eligible for fresher/trainee role

# %%
degree = input("Do you have a degree? ")

if degree == "yes":
    print("Degree verified")

    experience = int(input("Enter years of experience: "))

    if experience >= 1:
        print("Eligible for experienced role")
    else:
        print("Eligible for fresher/trainee role")

else:
    print("Not Eligible")
# Out:
# Do you have a degree?  yes
# Degree verified
# Enter years of experience:  5
# Eligible for experienced role

# %%
degree = input("Do you have a degree? ")

if degree == "yes":
    print("Degree verified")

    experience = int(input("Enter years of experience: "))

    if experience >= 1:
        print("Eligible for experienced role")
    else:
        print("Eligible for fresher/trainee role")

else:
    print("Not Eligible")
# Out:
# Do you have a degree?  no
# Not Eligible
